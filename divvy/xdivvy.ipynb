# %%
import pandas as pd
from datetime import datetime as dt
#import numpy as np
import csv

file_19 = "Resources/divvy_2019.csv"
file_20 = "Resources/divvy_2020.csv"
file_merged = "Resources/divvy_merged.csv"

#divvy19_df = pd.read_csv(file_19,low_memory=False,encoding = "ISO-8859-1")
divvy19_df = pd.read_csv(file_19)
divvy19_df
# Out:
#          trip_id           start_time             end_time  bikeid  \
# 0       21742443  2019-01-01 00:04:37  2019-01-01 00:11:07    2167
# 1       21742479  2019-01-01 00:48:44  2019-01-01 00:59:39    6336
# 2       21742517  2019-01-01 01:37:42  2019-01-01 01:45:00    1330
# 3       21742555  2019-01-01 02:27:58  2019-01-01 02:41:17    4692
# 4       21742594  2019-01-01 03:57:29  2019-01-01 04:02:01     976
# ...          ...                  ...                  ...     ...
# 106051  25962718  2019-12-31 19:52:14  2019-12-31 20:06:13    1817
# 106052  25962760  2019-12-31 20:38:09  2019-12-31 20:49:23    2484
# 106053  25962796  2019-12-31 21:34:06  2019-12-31 21:48:56    5458
# 106054  25962837  2019-12-31 22:54:51  2019-12-31 23:12:30     646
# 106055  25962874  2019-12-31 23:31:35  2019-12-31 23:50:47    3388
#
#        tripduration  from_station_id                    from_station_name  \
# 0             390.0              199               Wabash Ave & Grand Ave
# ...

# %%
divvy19_df.drop(['end_time','bikeid','usertype','gender','birthyear'],axis=1, inplace=True)
divvy19_df
# Out:
#          trip_id           start_time tripduration  from_station_id  \
# 0       21742443  2019-01-01 00:04:37        390.0              199
# 1       21742479  2019-01-01 00:48:44        655.0              304
# 2       21742517  2019-01-01 01:37:42        438.0              128
# 3       21742555  2019-01-01 02:27:58        799.0              482
# 4       21742594  2019-01-01 03:57:29        272.0              181
# ...          ...                  ...          ...              ...
# 106051  25962718  2019-12-31 19:52:14        838.0               53
# 106052  25962760  2019-12-31 20:38:09        674.0              173
# 106053  25962796  2019-12-31 21:34:06        889.0              326
# 106054  25962837  2019-12-31 22:54:51      1,059.0               38
# 106055  25962874  2019-12-31 23:31:35      1,152.0              174
#
#                           from_station_name  to_station_id  \
# 0                    Wabash Ave & Grand Ave             84
# ...

# %%
#divvy19_df['start_time'].groupby([df.birthdate.dt.year, df.birthdate.dt.month]).agg('count')

# %%
#divvy19b.index = divvy19_df.to_datetime(divvy19_df['start_time'],format='%y-%m-%d %H:%M:%S')
divvy19_df['start_time'] = pd.to_datetime(divvy19_df['start_time'],errors = 'coerce',format = '%Y-%m-%d %H:%M:%S').dt.strftime("%B")
divvy19_df
# Out:
#          trip_id start_time tripduration  from_station_id  \
# 0       21742443    January        390.0              199
# 1       21742479    January        655.0              304
# 2       21742517    January        438.0              128
# 3       21742555    January        799.0              482
# 4       21742594    January        272.0              181
# ...          ...        ...          ...              ...
# 106051  25962718   December        838.0               53
# 106052  25962760   December        674.0              173
# 106053  25962796   December        889.0              326
# 106054  25962837   December      1,059.0               38
# 106055  25962874   December      1,152.0              174
#
#                           from_station_name  to_station_id  \
# 0                    Wabash Ave & Grand Ave             84
# 1                   Broadway & Waveland Ave            332
# 2                   Damen Ave & Chicago Ave             54
# ...

# %%
divcnt = pd.value_counts(divvy19_df['start_time'])
divcnt = divcnt.to_frame().reset_index()

type(divcnt) #.head()
# Out:
# pandas.core.frame.DataFrame

# %%
#months = ["Janruary","February","March","April","May","June","July","August","September","October","November","December"]
#divcnt['Month'] = pd.Categorical(divcnt['Month'], categories=months, ordered=True)
#divcnt = pd.to_datetime(divcnt['index'],errors = 'coerce')
#divcnt["index"] = divcnt.sort_values(by='index',axis=0, ascending=True, inplace=True)
#divcnt.sort_values(by='index')
divcnt.rename(columns = {'index':'Month','start_time':'Rides'},inplace=True)
divcnt # .index
# Out:
#         Month  Rides
# 0      August  16393
# 1        July  15482
# 2   September  13700
# 3        June  13206
# 4     October  10327
# 5         May  10207
# 6       April   7370
# 7    November   4922
# 8       March   4600
# 9    December   4308
# 10    January   2869
# 11   February   2672

# %%
# Out:
#     trip_id           start_time             end_time tripduration  \
# 0  21742443  2019-01-01 00:04:37  2019-01-01 00:11:07        390.0
# 1  21742479  2019-01-01 00:48:44  2019-01-01 00:59:39        655.0
# 2  21742517  2019-01-01 01:37:42  2019-01-01 01:45:00        438.0
# 3  21742555  2019-01-01 02:27:58  2019-01-01 02:41:17        799.0
# 4  21742594  2019-01-01 03:57:29  2019-01-01 04:02:01        272.0
#
#    from_station_id            from_station_name  to_station_id  \
# 0              199       Wabash Ave & Grand Ave             84
# 1              304      Broadway & Waveland Ave            332
# 2              128      Damen Ave & Chicago Ave             54
# 3              482  Campbell Ave & Montrose Ave            293
# 4              181     LaSalle St & Illinois St            140
#
#                                to_station_name
# 0                    Milwaukee Ave & Grand Ave
# 1  Burling St (Halsted) & Diversey Pkwy (Temp)
# ...

# %%
divvy20_df = pd.read_csv(file_20,low_memory=False)
divvy20_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  EACB19130B0CDA4A   docked_bike  2020-01-21 20:06:59  2020-01-21 20:14:30
# 1  21A882AE9EABD44E   docked_bike  2020-01-21 19:13:09  2020-01-21 19:21:11
# 2  6112BC5112FF9518   docked_bike  2020-01-05 07:51:19  2020-01-05 07:55:37
# 3  1E76695F1AE80B1B   docked_bike  2020-01-26 08:54:09  2020-01-26 09:01:18
# 4  F3418D0C3ACA50B9   docked_bike  2020-01-08 18:52:36  2020-01-08 18:55:29
#
#              start_station_name start_station_id  \
# 0      Western Ave & Leland Ave              239
# 1  Milwaukee Ave & Wabansia Ave              158
# 2     Columbus Dr & Randolph St              195
# 3          Broadway & Barry Ave              300
# 4           Canal St & Adams St              192
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0                 Clark St & Leland Ave            326    41.9665   -87.6884
# ...

# %%
#divvy_df = pd.read_csv(file)
divvy_20_df = divvy20_df.rename(columns={'ride_id':'trip_id','started_at':'start_time','ended_at':'end_time','start_station_name':'from_station_name','start_station_id':'from_station_id','end_station_name':'to_station_name','end_station_id':'to_station_id'})
divvy_20_df
# Out:
#                 trip_id  rideable_type           start_time  \
# 0      EACB19130B0CDA4A    docked_bike  2020-01-21 20:06:59
# 1      21A882AE9EABD44E    docked_bike  2020-01-21 19:13:09
# 2      6112BC5112FF9518    docked_bike  2020-01-05 07:51:19
# 3      1E76695F1AE80B1B    docked_bike  2020-01-26 08:54:09
# 4      F3418D0C3ACA50B9    docked_bike  2020-01-08 18:52:36
# ...                 ...            ...                  ...
# 98375  48ED41248526C21B    docked_bike  2020-12-03 16:05:59
# 98376  64B92D133EAB5662   classic_bike  2020-12-09 14:05:22
# 98377  7BDA3EC496A0D15C   classic_bike  2020-12-13 08:54:12
# 98378  EA05A55FB3C3E921   classic_bike  2020-12-18 13:18:36
# 98379  FB351326E3592815  electric_bike  2020-12-01 14:21:21
#
#                   end_time             from_station_name from_station_id  \
# 0      2020-01-21 20:14:30      Western Ave & Leland Ave             239
# 1      2020-01-21 19:21:11  Milwaukee Ave & Wabansia Ave             158
# ...

# %%
#divvy_20_df = divvy20_df.reset_index()
#divvy_20_df = divvy20_df[["trip_id","start_time","end_time","from_station_name","from_station_id","to_station_name","to_station_id","start_lat","start_lng","end_lat","end_lng"]]
#divvy_20_df.drop(['rideable_type','member_casual'], axis=1, inplace=True)
divvy_20_df.head()
# Out:
#             trip_id           start_time             end_time  \
# 0  EACB19130B0CDA4A  2020-01-21 20:06:59  2020-01-21 20:14:30
# 1  21A882AE9EABD44E  2020-01-21 19:13:09  2020-01-21 19:21:11
# 2  6112BC5112FF9518  2020-01-05 07:51:19  2020-01-05 07:55:37
# 3  1E76695F1AE80B1B  2020-01-26 08:54:09  2020-01-26 09:01:18
# 4  F3418D0C3ACA50B9  2020-01-08 18:52:36  2020-01-08 18:55:29
#
#               from_station_name from_station_id  \
# 0      Western Ave & Leland Ave             239
# 1  Milwaukee Ave & Wabansia Ave             158
# 2     Columbus Dr & Randolph St             195
# 3          Broadway & Barry Ave             300
# 4           Canal St & Adams St             192
#
#                         to_station_name to_station_id  start_lat  start_lng  \
# 0                 Clark St & Leland Ave           326    41.9665   -87.6884
# 1  Damen Ave & Thomas St (Augusta Blvd)           183    41.9126   -87.6814
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-efb698af3ca6> in <module>
# ----> 1 divvy_20_pd = divvy_20_pd.rename(columns={'ride_id':'trip_id','started_at':'start_time','ended_at':'end_time','start_station_name':'from_station_name','start_station_id':'from_station_id','end_station_name':'to_station_name','end_station_id':'to_station_id'})
#       2
#
# NameError: name 'divvy_20_pd' is not defined
